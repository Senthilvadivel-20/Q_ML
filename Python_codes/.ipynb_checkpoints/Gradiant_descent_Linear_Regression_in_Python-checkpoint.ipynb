# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading csv

df = pd.read_csv("https://raw.githubusercontent.com/Senthilvadivel-20/Data/data/car.csv")
df = df.fillna(0)
df[['engine_size','price']].head()
# Out:
#    engine_size    price
# 0          130  13495.0
# 1          130  16500.0
# 2          152  16500.0
# 3          109  13950.0
# 4          136  17450.0

# %%
df[['engine_size','price']].corr()
# Out:
#              engine_size     price
# engine_size     1.000000  0.838097
# price           0.838097  1.000000

# %%
X = df['engine_size']
Y = df['price']

# %%
#Scatter plot

plt.scatter(X,Y)
plt.show()

# %%
# Building the model
m = 0
c = 0

L = 0.0001  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    print (m, c)
    
print (m, c)
# Out:
# 384.793116097561 2.5898858536585365
# -602.7380987229959 -4.587358668286968
# 1931.6707598459593 13.301819658449073
# -4572.64512138912 -33.13958557197289
# 12120.067685714872 85.51735305544327
# -30720.19074595882 -219.53491910937095
# 79225.26799883967 562.8222712372456
# -202939.307199021 -1445.5536485904784
# 521209.28325647186 3708.2219490560483
# -1337249.3020979392 -9518.984163821919
# 3432308.1737447586 24426.853756308385
# -8808308.146476142 -62692.44606824145
# 22606071.221413497 160890.43327143404
# -58015950.177511826 -412914.324584287
# 148892811.5316447 1059700.565062236
# -382118876.4425022 -2719626.233757375
# 980672193.5862157 6979656.563841708
# -2516801671.119545 -17912632.180842746
# 6459132867.445059 45971062.47289014
# -16576750732.310694 -117980373.71503636
# 42542656939.58135 302785417.195246
# -109181688616.32861 -777070027.9716218
# 280204435854.51624 1994276423.7871826
# -719118074813.6888 -5118121066.167298
# 1845548248839.5127 13135171667.321594
# ...

# %%
# Y_pred = m*X + c

# plt.scatter(X, Y) 
# plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  
# plt.show()

# %%
pd.read_csv('https://raw.githubusercontent.com/chasinginfinity/ml-from-scratch/master/02%20Linear%20Regression%20using%20Gradient%20Descent/data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4c6ec8be4f1d> in <module>
# ----> 1 pd.read_csv('https://raw.githubusercontent.com/chasinginfinity/ml-from-scratch/master/02%20Linear%20Regression%20using%20Gradient%20Descent/data.csv')
#
# NameError: name 'pd' is not defined
